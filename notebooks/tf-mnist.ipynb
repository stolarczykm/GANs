# %%
import os, sys
sys.path.append(os.path.abspath("../src/tf"))

# %%
from gan import MnistGan, MnistWgan
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 128.0 - 1, x_test / 255.0 - 1
x_train = x_train[:, :, :, np.newaxis]
x_test = x_test[:, :, :, np.newaxis]

sess = tf.Session()
gan = MnistWgan(sess, learning_rate=0.0001)
sess.run(gan.init_vars)
noise = np.random.normal(0, 1, (20, 100))
for i in range(20):
    gan.train(x_train[:5000], 5)

    pred = gan.generate(noise)
    plt.figure(figsize=(10, 10))
    for j in range(20):
        plt.subplot(4, 5, j+1)
        plt.imshow(pred[j,:,:,0], cmap="gray_r")
    plt.show()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/util/tf_should_use.py:118: initialize_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.variables_initializer` instead.
# Epoch 0: gen_loss: -81.45965576171875, disc_loss: -327.5444641113281
# Epoch 1: gen_loss: -299.16156005859375, disc_loss: -163.26953125
# Epoch 2: gen_loss: -355.6853332519531, disc_loss: -100.00198364257812
# Epoch 3: gen_loss: -389.265625, disc_loss: -72.094482421875
# Epoch 4: gen_loss: -415.71234130859375, disc_loss: -54.63323974609375
# Epoch 0: gen_loss: -423.25286865234375, disc_loss: -44.972938537597656
# Epoch 1: gen_loss: -415.79693603515625, disc_loss: -39.60572052001953
# Epoch 2: gen_loss: -391.4705505371094, disc_loss: -37.17149353027344
# Epoch 3: gen_loss: -363.9163513183594, disc_loss: -34.784244537353516
# Epoch 4: gen_loss: -334.2113342285156, disc_loss: -31.26115608215332
# ...

# %%
import matplotlib.pyplot as plt
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 128.0 - 1, x_test / 255.0 - 1
x_train = x_train[:, :, :, np.newaxis]
x_test = x_test[:, :, :, np.newaxis]

sess = tf.Session()
gan = MnistGan(sess)
sess.run(gan.init_vars)
noise = np.random.normal(0, 1, (20, 100))
for i in range(20):
    gan.train(x_train[:5000], 5)

    pred = gan.generate(noise)
    plt.figure(figsize=(10, 10))
    for j in range(20):
        plt.subplot(4, 5, j+1)
        plt.imshow(pred[j,:,:,0], cmap="gray_r")
    plt.show()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/util/tf_should_use.py:118: initialize_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.variables_initializer` instead.
# Epoch 0: gen_loss: 0.5995073318481445, disc_loss: 0.6604356169700623
# Epoch 1: gen_loss: 0.6274300217628479, disc_loss: 0.6123895645141602
# Epoch 2: gen_loss: 0.6645936369895935, disc_loss: 0.5735850930213928
# Epoch 3: gen_loss: 0.6914517879486084, disc_loss: 0.543474018573761
# Epoch 4: gen_loss: 0.6889505982398987, disc_loss: 0.5471356511116028
# Epoch 0: gen_loss: 0.6914522051811218, disc_loss: 0.5467260479927063
# Epoch 1: gen_loss: 0.6900172233581543, disc_loss: 0.5479161143302917
# Epoch 2: gen_loss: 0.6909782290458679, disc_loss: 0.5420430302619934
# Epoch 3: gen_loss: 0.6877074837684631, disc_loss: 0.5534611344337463
# ...
